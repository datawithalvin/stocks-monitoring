# %%
import pandas as pd
import numpy as np
import time
import datetime
from gnews import GNews
import nltk
from newspaper import Article

# %%
today = datetime.date.today()
today
# Out:
# datetime.date(2023, 8, 3)

# %%
# Set the parameters for the Google News API
google_news = GNews(language='id', country="Indonesia", max_results=20)
today = datetime.date.today()
google_news.start_date = today - datetime.timedelta(days=3)
google_news.end_date = today

get_news = google_news.get_news("BBCA")

news_df = pd.DataFrame(get_news)

# %%
news_df
# Out:
#                                                 title  \
# 0   Harga Saham BBCA Sudah Kemahalan, Bagaimana Me...
# 1   Harga Saham GOTO Melemah, BBCA Stagnan di Perd...
# 2   Analisis Saham BBCA Periode Agustus 2023 - Kom...
# 3   Simak Rekomendasi Saham INDF, ASII, BBCA, & PG...
# 4   Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
# 5   10 Emiten Terbesar RI, Nomor 7 Ada Tambang Rak...
# 6   Asing Ramai-Ramai Serbu Pasar Modal RI - CNBC ...
# 7   STAR AM Bidik Dana Kelolaan Rp100 M, Bank Jadi...
# 8   Bank Central Asia (BCA) Ambil Bagian Liga Bask...
# 9   ANALIS MARKET (01/8/2023) : IHSG Diperkirakan ...
# 10  Emiten Sudah Merilis Kinerja, Bursa Saham Masi...
# 11  Meski IHSG Terkoreksi, Pemodal Asing justru Ne...
# 12  Tekan Biaya Kredit, Bank-Bank Besar Catat Kena...
# 13  Top Stories: Nasdem Minta Anies Independen, Ka...
# 14  Peringkat Kredit AS Turun, Ekonom Sebut Rupiah...
# 15  Laba Perusahaan Pembuat Chip Kartu SIM Naik 5 ...
# 16  Infobank15 Kocok Ulang, Depak BJTM, BNBA Ganti...
# 17  OJK Sebut Tidak Batasi Besaran Rasio Dividen P...
# 18  Rupiah Loyo, Cek Kurs di BCA, BRI, Bank Mandir...
# 19  Kapitalisasi Pasar Bursa Efek Indonesia Tembus...
#
#                                           description  \
# 0   Harga Saham BBCA Sudah Kemahalan, Bagaimana Me...
# 1   Harga Saham GOTO Melemah, BBCA Stagnan di Perd...
# 2   Analisis Saham BBCA Periode Agustus 2023 - Kom...
# 3   Simak Rekomendasi Saham INDF, ASII, BBCA, & PG...
# 4   Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
# 5   10 Emiten Terbesar RI, Nomor 7 Ada Tambang Rak...
# 6   Asing Ramai-Ramai Serbu Pasar Modal RI  CNBC I...
# 7   STAR AM Bidik Dana Kelolaan Rp100 M, Bank Jadi...
# 8   Bank Central Asia (BCA) Ambil Bagian Liga Bask...
# 9   ANALIS MARKET (01/8/2023) : IHSG Diperkirakan ...
# 10  Emiten Sudah Merilis Kinerja, Bursa Saham Masi...
# 11  Meski IHSG Terkoreksi, Pemodal Asing justru Ne...
# 12  Tekan Biaya Kredit, Bank-Bank Besar Catat Kena...
# 13  Top Stories: Nasdem Minta Anies Independen, Ka...
# 14  Peringkat Kredit AS Turun, Ekonom Sebut Rupiah...
# 15  Laba Perusahaan Pembuat Chip Kartu SIM Naik 5 ...
# 16  Infobank15 Kocok Ulang, Depak BJTM, BNBA Ganti...
# 17  OJK Sebut Tidak Batasi Besaran Rasio Dividen P...
# 12  {'href': 'https://keuangan.kontan.co.id', 'tit...
# 13  {'href': 'https://katadata.co.id', 'title': 'K...
# 14  {'href': 'https://ekonomi.bisnis.com', 'title'...
# 15  {'href': 'https://www.fortuneidn.com', 'title'...
# 16  {'href': 'https://www.emitennews.com', 'title'...
# 17  {'href': 'https://finansial.bisnis.com', 'titl...
# 18  {'href': 'https://finansial.bisnis.com', 'titl...
# 19  {'href': 'https://www.inews.id', 'title': 'iNe...

# %%
articles = []
images = []

for column, url in news_df["url"].items():
    try:
        # Download the article content and extract the text
        # get_article = google_news.get_full_article(url)
        # full_text = get_article.text
        get_article = Article(url)
        get_article.download()
        get_article.parse()
        
        full_text = get_article.text
        
        # Try to get the image URL and append it to the list
        if len(get_article.images) > 0:
            image = list(get_article.images)[0] if get_article.images else None
            images.append(image)
        else:
            images.append(None)
        
        articles.append(full_text)

    except Exception as e:
        # If there is an error, append an error message to the summary list and set the image URL to None
        print(f"Error downloading article from {url}: {e}")
        articles.append("Error: article download failed")
        images.append(None)

    # Sleep for a short time to avoid being blocked by the website
    time.sleep(5)

# Add the full text and image URL columns to the DataFrame
news_df["full_text"] = articles
news_df['image_url'] = images

# %%
news_df
# Out:
#                                                 title  \
# 0   Harga Saham BBCA Sudah Kemahalan, Bagaimana Me...
# 1   Harga Saham GOTO Melemah, BBCA Stagnan di Perd...
# 2   Analisis Saham BBCA Periode Agustus 2023 - Kom...
# 3   Simak Rekomendasi Saham INDF, ASII, BBCA, & PG...
# 4   Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
# 5   10 Emiten Terbesar RI, Nomor 7 Ada Tambang Rak...
# 6   Asing Ramai-Ramai Serbu Pasar Modal RI - CNBC ...
# 7   STAR AM Bidik Dana Kelolaan Rp100 M, Bank Jadi...
# 8   Bank Central Asia (BCA) Ambil Bagian Liga Bask...
# 9   ANALIS MARKET (01/8/2023) : IHSG Diperkirakan ...
# 10  Emiten Sudah Merilis Kinerja, Bursa Saham Masi...
# 11  Meski IHSG Terkoreksi, Pemodal Asing justru Ne...
# 12  Tekan Biaya Kredit, Bank-Bank Besar Catat Kena...
# 13  Top Stories: Nasdem Minta Anies Independen, Ka...
# 14  Peringkat Kredit AS Turun, Ekonom Sebut Rupiah...
# 15  Laba Perusahaan Pembuat Chip Kartu SIM Naik 5 ...
# 16  Infobank15 Kocok Ulang, Depak BJTM, BNBA Ganti...
# 17  OJK Sebut Tidak Batasi Besaran Rasio Dividen P...
# 18  Rupiah Loyo, Cek Kurs di BCA, BRI, Bank Mandir...
# 19  Kapitalisasi Pasar Bursa Efek Indonesia Tembus...
#
#                                           description  \
# 0   Harga Saham BBCA Sudah Kemahalan, Bagaimana Me...
# 1   Harga Saham GOTO Melemah, BBCA Stagnan di Perd...
# 2   Analisis Saham BBCA Periode Agustus 2023 - Kom...
# 3   Simak Rekomendasi Saham INDF, ASII, BBCA, & PG...
# 4   Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
# 5   10 Emiten Terbesar RI, Nomor 7 Ada Tambang Rak...
# 6   Asing Ramai-Ramai Serbu Pasar Modal RI  CNBC I...
# 19  https://news.google.com/rss/articles/CBMiamh0d...
#
#                                             publisher  \
# 0   {'href': 'https://katadata.co.id', 'title': 'K...
# 1   {'href': 'https://investasi.kontan.co.id', 'ti...
# 2   {'href': 'https://www.kompasiana.com', 'title'...
# 3   {'href': 'https://investasi.kontan.co.id', 'ti...
# 4   {'href': 'https://investasi.kontan.co.id', 'ti...
# 5   {'href': 'https://www.cnbcindonesia.com', 'tit...
# 6   {'href': 'https://www.cnbcindonesia.com', 'tit...
# 7   {'href': 'https://www.cnbcindonesia.com', 'tit...
# 8   {'href': 'https://pressrelease.kontan.co.id', ...
# 9   {'href': 'https://pasardana.id', 'title': 'Pas...
# 10  {'href': 'https://insight.kontan.co.id', 'titl...
# 11  {'href': 'https://investor.id', 'title': 'Inve...
# 12  {'href': 'https://keuangan.kontan.co.id', 'tit...
# 13  {'href': 'https://katadata.co.id', 'title': 'K...
# 14  {'href': 'https://ekonomi.bisnis.com', 'title'...
# 15  {'href': 'https://www.fortuneidn.com', 'title'...
# 16  {'href': 'https://www.emitennews.com', 'title'...
# 17  {'href': 'https://finansial.bisnis.com', 'titl...
# 18  {'href': 'https://finansial.bisnis.com', 'titl...
# 19  {'href': 'https://www.inews.id', 'title': 'iNe...
#
#                                             full_text  \
# 0   PT Bank Central Asia Tbk (BCA) menjadi salah s...
# 1   Penulis: Bimo Kresnomurti\n\nHarga Saham GOTO ...
# 2   Analisa pertumbuhan Bank BCA dengan kode saham...
# 3   Reporter: Akmalal Hamdhi | Editor: Wahyu T.Rah...
# 4   Reporter: Pulina Nityakanti | Editor: Wahyu T....
# 5   Jakarta, CNBC Indonesia - Harga saham PT Amman...
# 6   Jakarta, CNBC Indonesia - Otoritas Jasa Keuang...
# 7   Jakarta, CNBC Indonesia — Manajer Investasi PT...
# 8   BANK CENTRAL ASIA - JAKARTA. Sebagai bagian da...
# 9   Pasardana.id – Riset harian Samuel Sekuritas m...
# 10  Berita Saham\n\nSelasa, 01 Agustus 2023 | 05:4...
# 11  JAKARTA, investor.id – Pemodal asing membukuka...
# 12  Reporter: Adrianus Octaviano | Editor: Herlina...
# 13  Bursa nama bakal calon wakil presiden (cawapre...
# 14  Smallest Font Largest Font\n\nBisnis.com, JAKA...
# 15  Jakarta, FORTUNE - Emiten solusi teknologi dan...
# 16  Dengan perubahan ini, berikut ini daftar 15 em...
# 17  OJK tidak membatasi rasio pembayaran dividen a...
# 18  Rupiah bergerak melemah di tengah fluktuasi ma...
# 19  JAKARTA, iNews.id - Nilai kapitalisasi pasar (...
#
#                                             image_url
# 0   https://cdn1.katadata.co.id/media/images/thumb...
# 1   https://foto.kontan.co.id/ZX7RD5ALN3wrBFqhsEpz...
# 2   https://assets-a2.kompasiana.com/items/album/2...
# 3   https://assets.kontan.co.id/live/general/img/l...
# 4   https://foto.kontan.co.id/vBFvcgU_3qB_wBd5mx7c...
# 5   https://cdn.cnbcindonesia.com/cnbc/images/apps...
# 6   https://cdn.cnbcindonesia.com/cnbc/images/logo...
# 7   https://akcdn.detik.net.id/visual/2018/12/19/b...
ibanding harga saat itu (Rp 114).\n\nAdapun sejak setahun lalu (01 Agustus 2022) harga saham GOTO turun -60.84% dari harga saat itu (Rp 286).\n\nBursa Efek Indonesia (BEI) mencatat total nilai transaksi saham GOTO mencapai Rp 191,30 miliar, sedangkan volume saham yang ditransaksikan mencapai 16.845.601 lot.\n\nDengan earning per share (EPS) alias laba bersih per saham Rp -13, maka price to earning ratio (PER) saham ini -8,69 kali. Adapun price to book value-nya (PBV) 1,10 kali.\n\nCek Berita dan Artikel yang lain di Google News\n\nDONASI, Dapat Voucer Gratis!\n\n\n\nSebagai ungkapan terimakasih atas perhatian Anda, tersedia voucer gratis senilai donasi yang bisa digunakan berbelanja di Dukungan Anda akan menambah semangat kami untuk menyajikan artikel-artikel yang berkualitas dan bermanfaat.Sebagai ungkapan terimakasih atas perhatian Anda, tersedia voucer gratis senilai donasi yang bisa digunakan berbelanja di KONTAN Store DUKUNG KONTAN'

# %%
# Clean the full text column
news_df["full_text"] = news_df["full_text"].replace("\n", "||", regex=True)
news_df["full_text"] = news_df["full_text"].replace("\r", "||", regex=True)
news_df["full_text"] = news_df["full_text"].replace(r"\\", "", regex=True)

# %%
# Rename the columns and select the desired columns for the final DataFrame
news_df = news_df.rename(columns={"published date":"published_time"})
news_df["source_publisher"] = news_df["publisher"].apply(lambda x: x["title"])
news_df["entity"] = "BBCA"

news_df["published_time"] = pd.to_datetime(news_df["published_time"])
news_df["published_date"] = news_df["published_time"].dt.date

news_df = news_df[["entity", "source_publisher", "title", "full_text", "url","published_time", "published_date", "image_url"]]
news_df.head()
# Out:
#   entity  source_publisher                                              title  \
# 0   BBCA    Katadata.co.id  Harga Saham BBCA Sudah Kemahalan, Bagaimana Me...
# 1   BBCA  Investasi Kontan  Harga Saham GOTO Melemah, BBCA Stagnan di Perd...
# 2   BBCA    Kompasiana.com  Analisis Saham BBCA Periode Agustus 2023 - Kom...
# 3   BBCA  Investasi Kontan  Simak Rekomendasi Saham INDF, ASII, BBCA, & PG...
# 4   BBCA  Investasi Kontan  Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
#
#                                            full_text  \
# 0  PT Bank Central Asia Tbk (BCA) menjadi salah s...
# 1  Penulis: Bimo Kresnomurti||||Harga Saham GOTO ...
# 2  Analisa pertumbuhan Bank BCA dengan kode saham...
# 3  Reporter: Akmalal Hamdhi | Editor: Wahyu T.Rah...
# 4  Reporter: Pulina Nityakanti | Editor: Wahyu T....
#
#                                                  url      published_time  \
# 0  https://news.google.com/rss/articles/CBMiemh0d... 2023-08-01 08:10:00
# 1  https://news.google.com/rss/articles/CBMiZ2h0d... 2023-08-01 09:30:29
# 2  https://news.google.com/rss/articles/CBMigAFod... 2023-08-02 02:00:00
# 3  https://news.google.com/rss/articles/CBMiXWh0d... 2023-08-01 22:20:51
# 4  https://news.google.com/rss/articles/CBMiVmh0d... 2023-08-02 15:28:45
#
#   published_date                                          image_url
# 0     2023-08-01  https://cdn1.katadata.co.id/media/images/thumb...
# 1     2023-08-01  https://foto.kontan.co.id/ZX7RD5ALN3wrBFqhsEpz...
# 2     2023-08-02  https://assets-a2.kompasiana.com/items/album/2...
# 3     2023-08-01  https://assets.kontan.co.id/live/general/img/l...
# 4     2023-08-02  https://foto.kontan.co.id/vBFvcgU_3qB_wBd5mx7c...

# %%
def fetch_daily_stock_articles(stock_code, n_days=2, max_articles=25):
    """
    Fetch daily stock articles based on the stock code and the number of days up to the current date.
    
    Args:
        stock_code (str): The stock code to search for news articles
        n_days (int): Fetch news from the past n days up to the current date
        max_articles (int): Max number of articles to fetch
    Returns:
        fetched_news_df (pandas.DataFrame): The DataFrame containing the retrieved news articles related to the stock code.
    """
    # Initialize GNews
    google_news = GNews(language='id', country="Indonesia", max_results=max_articles)
    
    # Get the current date and calculate the start date
    today = datetime.date.today()
    google_news.start_date = today - datetime.timedelta(days=n_days)
    google_news.end_date = today

    # Fetch the news articles from Google News
    news_items = google_news.get_news(f"{stock_code}")
    fetched_news_df = pd.DataFrame(news_items)
    
    # Initialize lists to store article full text and images
    full_texts = []
    image_urls = []

    # Iterate through each URL in the fetched news DataFrame
    for url in fetched_news_df["url"]:
        # Download and parse the article
        article = Article(url)
        
        try:
            article.download()
            article.parse()
            
            # Get the full text of the article
            full_text = article.text
            full_texts.append(full_text)
            
            # Get the first image from the article
            image = list(article.images)[0] if article.images else None
            image_urls.append(image)
            
        except Exception as e:
            print(f"Error when downloading and parsing article from {url}: {e}")
            # Add placeholder values for the article and image
            full_texts.append(f"Error when downloading and parsing article from {url}: {e}")
            image_urls.append(f"Error when downloading and parsing article from {url}: {e}")

        # Sleep to avoid getting blocked
        time.sleep(10)

    # Add the article full text and image URL to the DataFrame
    fetched_news_df["full_text"] = full_texts
    fetched_news_df["image_url"] = image_urls

    # Add the entity to the DataFrame
    fetched_news_df["entity"] = f"{stock_code}"

    return fetched_news_df

# %%
bmri_df = fetch_daily_stock_articles("BBCA", n_days=3, max_articles=20)
bmri_df
# Out:
#                                                 title  \
# 0   Terbaru, Segini Harta Duo Hartono di Bank BCA ...
# 1   Kompak Memerah, Cek Harga Saham BBCA dan GOTO ...
# 2   Analis RHB Sekuritas: Buy Saham BBCA, UNVR, NC...
# 3   Prospek Grup Djarum Milik Orang Terkaya RI BBC...
# 4   Saham Sejuta Umat, Deretan Emiten Idola Invest...
# 5   Maaf Batu Bara, Minat Bank Jumbo Salurkan Kred...
# 6   Dana Asing Tinggalkan Pasar Saham Sepekan Tera...
# 7     Cuan Ekuitas Bank Masih Tumbuh - Insight Kontan
# 8   Bursa Asia Bervariasi pada Jumat (4/8) Pagi, D...
# 9   Geliat Bank Andalkan Fee Based Income Guna Rau...
# 10  Penyaluran Kredit Perbankan Diramal Makin Kenc...
# 11  10 Emiten Siap Tebar Dividen Interim Gede, Ini...
# 12  Punya Saham PWON, SMGR, INTP hingga MDKA, Cuan...
# 13  Bank Central Asia (BCA) Ambil Bagian Liga Bask...
# 14  Star Asset Management Luncurkan Reksa Dana Ind...
# 15  Saat IHSG Anjlok, Investor Asing Gelar Aksi Ju...
# 16  Pemburu Dividen Wajib Tahu sama Saham-Saham Be...
# 17  Rupiah Menguat, Cek Kurs Dolar di BCA, BRI, Ba...
# 8   https://news.google.com/rss/articles/CBMidGh0d...
# 9   https://news.google.com/rss/articles/CBMidGh0d...
# 10  https://news.google.com/rss/articles/CBMib2h0d...
# 11  https://news.google.com/rss/articles/CBMiW2h0d...
# 12  https://news.google.com/rss/articles/CBMiiQFod...
# 13  https://news.google.com/rss/articles/CBMiaGh0d...
# 14  https://news.google.com/rss/articles/CBMiY2h0d...
# 15  https://news.google.com/rss/articles/CBMiX2h0d...
# 16  https://news.google.com/rss/articles/CBMiVGh0d...
# 17  https://news.google.com/rss/articles/CBMiiQFod...
# 18  https://news.google.com/rss/articles/CBMihAFod...
# 19  https://news.google.com/rss/articles/CBMieWh0d...
#
#                                             publisher  \
# 0   {'href': 'https://investor.id', 'title': 'Inve...
# 1   {'href': 'https://investasi.kontan.co.id', 'ti...
# 2   {'href': 'https://investasi.kontan.co.id', 'ti...
# 3   {'href': 'https://market.bisnis.com', 'title':...
# 4   {'href': 'https://www.idxchannel.com', 'title'...
# 5   {'href': 'https://www.cnbcindonesia.com', 'tit...
# 6   {'href': 'https://investasi.kontan.co.id', 'ti...
# 7   {'href': 'https://insight.kontan.co.id', 'titl...
# 8   {'href': 'https://investasi.kontan.co.id', 'ti...
# 9   {'href': 'https://finansial.bisnis.com', 'titl...
# 10  {'href': 'https://keuangan.kontan.co.id', 'tit...
# 11  {'href': 'https://investor.id', 'title': 'Inve...
# 12  {'href': 'https://www.bareksa.com', 'title': '...
# 13  {'href': 'https://pressrelease.kontan.co.id', ...
# 14  {'href': 'https://investor.id', 'title': 'Inve...
# 15  {'href': 'https://investor.id', 'title': 'Inve...
# 16  {'href': 'https://investor.id', 'title': 'Inve...
# 17  {'href': 'https://finansial.bisnis.com', 'titl...
# 18  {'href': 'https://www.liputan6.com', 'title': ...
# 19  {'href': 'https://finansial.bisnis.com', 'titl...
#
#                                             full_text  \
# 0   JAKARTA, investor.id - PT Bank Central Asia Tb...
# 1   Penulis: Bimo Kresnomurti\n\nHarga Saham BBCA ...
# 2   Reporter: Yuliana Hema | Editor: Yudho Winarto...
# 3   Emiten Grup Djarum milik orang terkaya RI menc...
# 4   IDXChannel – Sejumlah saham berkapitalisasi pa...
# 5   Jakarta, CNBC Indonesia - Sejumlah raksasa per...
# 6   Reporter: Pulina Nityakanti | Editor: Wahyu T....
# 7   Berita Keuangan\n\nKamis, 03 Agustus 2023 | 06...
# 8   Reporter: Yudho Winarto | Editor: Yudho Winart...
# 9   Sejumlah bank mencatatkan pertumbuhan fee base...
# 10  Reporter: Nurtiandriyani Simamora | Editor: Te...
# 11  JAKARTA, Investor.id – Sebanyak 10 emiten dipr...
# 12  BNP Paribas Solaris dan Reksa Dana Bahana Prim...
# 13  BANK CENTRAL ASIA - JAKARTA. Sebagai bagian da...
# 14  JAKARTA, investor.id - PT Star Asset Managemen...
# 15  JAKARTA, investor.id – Investor asing membukuk...
# 16  JAKARTA, investor.id - Bursa Efek Indonesia (B...
# 17  Nilai tukar rupiah dibuka menguat ke level Rp1...
# 18  Liputan6.com, Jakarta Otoritas Jasa Keuangan (...
# 19  Sejumlah bank memacu kredit konsumer melalui b...
#
#                                             image_url entity
# 0   https://img2.beritasatu.com/cache/investor/253...   BBCA
# 1   https://foto.kontan.co.id/KWXpLeWOnROx58ZjvoZQ...   BBCA
# 2   https://foto.kontan.co.id/ZX7RD5ALN3wrBFqhsEpz...   BBCA
# 3   https://cdn.bisnis.com/bisnis-web/assets/image...   BBCA
# 4   https://img.idxchannel.com/media/439/images/id...   BBCA
# 5   https://akcdn.detik.net.id/visual/2019/08/15/8...   BBCA
# 6   https://foto.kontan.co.id/PyZmBC6Xz66yzQp_UhuZ...   BBCA
# 7   https://dev-web.xendit.co/wp-content/uploads/2...   BBCA
# 8   https://foto.kontan.co.id/bZGH6moqbVxvzfDFWAOM...   BBCA
# 9   https://images.bisnis.com/thumb/lock/3797/ed68...   BBCA
# 10  https://foto.kontan.co.id/xOYCnATA43TDcpZMabaW...   BBCA
# 11  https://img2.beritasatu.com/cache/investor/253...   BBCA
# 12  https://images.bareksa.com/biome/icons/angle-r...   BBCA
# 13  https://foto.kontan.co.id/SeZSyU_ZSCZYt82O0Yaj...   BBCA
# 14  https://img2.beritasatu.com/cache/investor/253...   BBCA
# 15  https://img2.beritasatu.com/cache/investor/253...   BBCA
# 16  https://img2.beritasatu.com/cache/investor/253...   BBCA
# 17  https://images.bisnis.com/thumb/lock/3797/ed68...   BBCA
# 18  https://cdn1-production-assets-kly.akamaized.n...   BBCA
# 19  https://cdn.bisnis.com/bisnis-web/assets/image...   BBCA

# %%
def cleaning_fetched_articles(df):
    """
    Clean up the dataframe that contains the fetched articles. This function will remove unnecessary characters from the 
    full text articles such as html tags, rename some columns, and also extract informations like date published and publisher name.

    Args:
        df (Pandas DataFrame): The dataframe that contains the fetched articles
    Returns:
        fetched_news_df (Pandas DataFrame): The cleaned dataframe
    """
    # Copy from the original dataframe
    fetched_news_df = df.copy()

    # Exclude the rows that contain error messages
    fetched_news_df = fetched_news_df[~fetched_news_df["full_text"].str.contains("Error when downloading and parsing article")]

    # Clean the full text column
    fetched_news_df["full_text"] = fetched_news_df["full_text"].replace("\n", "||", regex=True)
    fetched_news_df["full_text"] = fetched_news_df["full_text"].replace("\r", "||", regex=True)
    fetched_news_df["full_text"] = fetched_news_df["full_text"].replace(r"\\", "", regex=True)

    # Rename the columns, extrack publisher and published date
    fetched_news_df = fetched_news_df.rename(columns={"published date":"published_time"})
    fetched_news_df["source_publisher"] = fetched_news_df["publisher"].apply(lambda x: x["title"])

    fetched_news_df["published_time"] = pd.to_datetime(fetched_news_df["published_time"])
    fetched_news_df["published_date"] = fetched_news_df["published_time"].dt.date

    # Reorder the columns
    fetched_news_df = fetched_news_df[["entity", "source_publisher", "title", "full_text", "url","published_time", "published_date", "image_url"]]
    
    return fetched_news_df

# %%
bmri_df_2 = cleaning_fetched_articles(bmri_df)
bmri_df_2
# Out:
#    entity  source_publisher  \
# 0    BBCA       Investor.ID
# 1    BBCA  Investasi Kontan
# 2    BBCA  Investasi Kontan
# 3    BBCA        Bisnis.com
# 4    BBCA        idxchannel
# 5    BBCA    CNBC Indonesia
# 6    BBCA  Investasi Kontan
# 7    BBCA    Insight Kontan
# 8    BBCA  Investasi Kontan
